# %%
import yfinance as yf

# %%
gold = yf.download(tickers="GC=F", period="120d", interval="5m")
# Out:
# $GC=F: possibly delisted; no price data found  (period=120d) (Yahoo error = "5m data not available for startTime=1768164078 and endTime=1778532078. The requested range must be within the last 60 days.")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GC=F']: possibly delisted; no price data found  (period=120d) (Yahoo error = "5m data not available for startTime=1768164078 and endTime=1778532078. The requested range must be within the last 60 days.")

# %%
gold.shape
# Out:
# (0, 6)
